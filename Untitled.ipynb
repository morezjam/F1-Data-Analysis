# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np

# %%
data = pd.read_csv("Dataset/circuits.csv")
data.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng  alt  \
# 0  Australia -37.84970  144.96800   10
# 1   Malaysia   2.76083  101.73800   18
# 2    Bahrain  26.03250   50.51060    7
# 3      Spain  41.57000    2.26111  109
# 4     Turkey  40.95170   29.40500  130
#
#                                                  url
# 0  http://en.wikipedia.org/wiki/Melbourne_Grand_P...
# 1  http://en.wikipedia.org/wiki/Sepang_Internatio...
# 2  http://en.wikipedia.org/wiki/Bahrain_Internati...
# 3  http://en.wikipedia.org/wiki/Circuit_de_Barcel...
# ...

# %%
d = data.groupby(data.country).count()
d["country"] = d.index
d = d[["country", "circuitId"]]
d.plot("country","circuitId",kind="bar",figsize=(15,5),color="green")
plt.xlabel("Country", size=20)
plt.ylabel("Number of Circuits", size=20)
plt.legend(fontsize=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.show()

# %%
data = pd.read_csv("Dataset/races.csv")
data.head()
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...

# %%
d = data.groupby("year", as_index = False).count()
d = d[["year", "raceId"]]
d = d.rename(columns={"raceId": "number of races"})
d.plot(x="year", y="number of races", kind="bar", figsize=(35,10))
plt.xlabel("season_year",size=40)
plt.ylabel("number of races per season", size = 40)
plt.xticks(size=25)
plt.yticks(size=25)
plt.legend(fontsize=25)
plt.show()

# %%
data3 = pd.read_csv("Dataset/constructors.csv")
data3.head()
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
# 3              4        renault     Renault      French
# 4              5     toro_rosso  Toro Rosso     Italian
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3  http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4   http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso

# %%
d3 = data3.groupby("nationality").count()
d3["nationality"] = d3.index
d3 = d3[["nationality", "constructorId"]]
d3.reset_index(drop=True, inplace = True)
d3.plot(x="nationality", y = "constructorId", kind="bar", figsize=(30,10),color="cyan")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("nationality", size=25)
plt.ylabel("number of constructors", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
data4 = pd.read_csv("Dataset/drivers.csv")
data4.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
d4 = data4.groupby("nationality").count()
d4["nationality"] = d4.index
d4 = d4[["nationality", "driverId"]]
d4.reset_index(drop=True, inplace = True)
d4.plot(x="nationality", y = "driverId", kind="bar", figsize=(30,10),color="brown")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("nationality", size=25)
plt.ylabel("number of drivers", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
data5 = pd.read_csv("Dataset/constructor_results.csv")
data5.head()
# Out:
#    constructorResultsId  raceId  constructorId  points status
# 0                     1      18              1    14.0     \N
# 1                     2      18              2     8.0     \N
# 2                     3      18              3     9.0     \N
# 3                     4      18              4     5.0     \N
# 4                     5      18              5     2.0     \N

# %%
d5 = data5.groupby("constructorId", as_index=False).count()
d5 = d5.apply(lambda x: x)
d5 = pd.merge(data3, d5, on="constructorId")
d5 = d5[["points", "constructorId", "name"]]
d5_a = d5.loc[(d5["constructorId"] > 0) & (d5["constructorId"] <= 72)]
d5_a.plot(x="name", y = "points", kind="bar", figsize=(30,10),color="blue")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Constructor name", size=25)
plt.ylabel("Points", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
d5_b = d5.loc[(d5["constructorId"] > 72) & (d5["constructorId"] <= 134)]
d5_b.plot(x="name", y = "points", kind="bar", figsize=(30,10),color="blue")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Constructor name", size=25)
plt.ylabel("Points", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
d5_c = d5.loc[(d5["constructorId"] > 163) & (d5["constructorId"] <= 214)]
d5_c.plot(x="name", y = "points", kind="bar", figsize=(30,10),color="blue")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Constructor name", size=25)
plt.ylabel("Points", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
data6 = pd.read_csv("Dataset/constructor_standings.csv")
data6.head()
# Out:
#    constructorStandingsId  raceId  constructorId  points  position  \
# 0                       1      18              1    14.0         1
# 1                       2      18              2     8.0         3
# 2                       3      18              3     9.0         2
# 3                       4      18              4     5.0         4
# 4                       5      18              5     2.0         5
#
#   positionText  wins
# 0            1     1
# 1            3     0
# 2            2     0
# 3            4     0
# 4            5     0

# %%
d6 = data6.groupby("constructorId", as_index=False).count()
d6 = d6.apply(lambda x: x)
d6 = pd.merge(data3, d6, on="constructorId")
d6 = d6[["raceId", "constructorId", "name"]]
d6_a = d6.loc[(d6["constructorId"] > 0) & (d6["constructorId"] <= 72)]
d6_a.plot(x="name", y = "raceId", kind="bar", figsize=(30,10),color="red")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Constructor name", size=25)
plt.ylabel("Number of Races", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
d6_b = d6.loc[(d6["constructorId"] > 72) & (d6["constructorId"] <= 140)]
d6_b.plot(x="name", y = "raceId", kind="bar", figsize=(30,10),color="red")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Constructor name", size=25)
plt.ylabel("Number of Races", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
d6_c = d6.loc[(d6["constructorId"] > 131) & (d6["constructorId"] <= 214)]
d6_c.plot(x="name", y = "raceId", kind="bar", figsize=(30,10),color="red")
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Constructor name", size=25)
plt.ylabel("Number of Races", size = 25)
plt.legend(fontsize=25)
plt.show()

# %%
data7 = pd.read_csv("Dataset/lap_times.csv")
result = pd.merge(data7,data2,on="raceId")
cid = result.circuitId.unique()
dr = result.groupby("circuitId", as_index=False)["milliseconds"].agg(min)
dr = pd.merge(dr,data2,on="circuitId")
dr = dr[["date", "milliseconds"]]
dr["date"] = pd.to_datetime(dr["date"])
dr.index = dr.date
dr = dr.drop("date", axis=1)
plt.rcParams["figure.figsize"] = [12.0,8.0]
start_date = datetime(1995,1,1)
end_date = datetime(2022,1,1)
dr[(start_date <= dr.index) & (dr.index <= end_date)].plot(grid=True, figsize=(20,10))
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Year", size=25)
plt.ylabel("Lap time ms", size = 25)
plt.legend(fontsize=25, loc="best")
plt.show()

# %%
data8 = pd.read_csv("Dataset/pit_stops.csv")
result2 = pd.merge(data8,data5, on="raceId")
result2 = pd.merge(result2, data2, on="raceId")
result2 = result2[result2.circuitId == 7]
dr2 = result2.groupby("constructorId", as_index=False)[["date", "milliseconds"]]
dr2 = dr2.apply(lambda x: x)
dr2["date"] = pd.to_datetime(dr2["date"])
dr2.index = dr2.date
dr2 = dr2.drop("date", axis=1)
plt.rcParams["figure.figsize"] = [12.0,8.0]
start_date = datetime(1995,1,1)
end_date = datetime(2022,1,1)
dr2[(start_date <= dr2.index) & (dr2.index <= end_date)].plot(grid=True, figsize=(20,10))
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel("Year", size=25)
plt.ylabel("Pit Stops for circuit ID 5 (ms)", size = 25)
plt.legend(fontsize=25, loc="best")
plt.show()

# %%
import pandas as pd
import numpy as np
import sqlite3
import json

# %%
def establish_database(db_name = "F1Results.db"):
    conn = sqlite3.connect(db_name)
    cur = conn.cursor()
    cur.execute("DROP TABLE IF EXISTS constructors")
    conn.commit()
    cur.execute("""CREATE TABLE constructors
    (constructorId  INT(3) PRIMARY KEY NOT NULL,constructorRef VARCHAR(30) unique not null,
    name VARCHAR(20) not null,
    nationality VARCHAR(20) not null,
    url VARCHAR(50) not null);""")
    conn.commit()
    
    cur.execute("DROP TABLE IF EXISTS drivers")
    conn.commit()
    cur.execute("""CREATE TABLE drivers
    (driverId  INT(5) PRIMARY KEY NOT NULL, driverRef VARCHAR(30) not null,
    number INT(10) not null,
    code VARCHAR(10) not null,
    forename VARCHAR(20) not null,
    surname VARCHAR(20) not null,
    dob DATE not null,
    nationality VARCHAR(20) not null,
    url VARCHAR(50) not null);""")
    conn.commit()
    
    cur.execute("DROP TABLE IF EXISTS circuits")
    conn.commit()
    cur.execute("""CREATE TABLE circuits
    (circuitId  INT(5) PRIMARY KEY NOT NULL, driverId INT(5) not null,
    stop INT(5) not null,
    lap INT(5) not null,
    time TIME not null,
    duration DECIMAL(2,3),
    milliseconds INT(8) not null);""")
    conn.commit()
    
    cur.execute("DROP TABLE IF EXISTS races")
    conn.commit()
    cur.execute("""CREATE TABLE races
    (raceId  INT(5) PRIMARY KEY NOT NULL, circuitRef VARCHAR(20) not null,
    name VARCHAR(20) not null,
    location VARCHAR(30) not null,
    country VARCHAR(20) not null,
    lat DECIMAL(3,5) not null,
    lng DECIMAL(3,5) not null,
    alt INT(4) not null,
    url VARCHAR(50) not null);""")
    conn.commit()
    
    cur.execute("DROP TABLE IF EXISTS pit_stops")
    conn.commit()
    cur.execute("""CREATE TABLE pit_stops
    (raceId  INT(5) PRIMARY KEY NOT NULL, driverId INT(5) not null,
    stop INT(5) not null,
    lap INT(5) not null,
    time TIME not null,
    duration DECIMAL(2,3),
    milliseconds INT(8) not null,
    FOREIGN KEY(driverId) REFERENCES drivers(driverId));""")
    conn.commit()
    
    cur.execute("DROP TABLE IF EXISTS lap_times")
    conn.commit()
    cur.execute("""CREATE TABLE lap_times
    (raceId  INT(5) PRIMARY KEY NOT NULL, driverId INT(5) not null,
    lap INT(5) not null,
    position INT(5) not null,
    time TIME not null,
    milliseconds INT(8) not null,
    FOREIGN KEY(raceId) REFERENCES races(raceId));""")
    conn.commit()
    
    cur.execute("DROP TABLE IF EXISTS constructor_standings")
    conn.commit()
    cur.execute("""CREATE TABLE constructor_standings
    (constructorStandingsId INT(5) PRIMARY KEY NOT NULL, raceId INT(5) not null,
    constructorId INT(5) not null,
    points INT(5) not null,
    position INT(5) not null,
    positionText VARCHAR(5) not null,
    wins INT(5) not null);""")
    conn.commit()
    
    conn.close()
    print("Database and its tables were built!\n")

# %%
def populate_tables():
    conn = sqlite3.connect("F1Results.db")
    cur = conn.cursor()
    
    df = pd.read_csv("Dataset/constructors.csv")
    df.to_sql("constructors", conn, if_exists = "replace", index = False)
    
    df = pd.read_csv("Dataset/drivers.csv")
    df.to_sql("drivers", conn, if_exists = "replace", index = False)
    
    df = pd.read_csv("Dataset/races.csv")
    df.to_sql("races", conn, if_exists = "replace", index = False)
    
    df = pd.read_csv("Dataset/pit_stops.csv")
    df.to_sql("pit_stops", conn, if_exists = "replace", index = False)
    
    df = pd.read_csv("Dataset/circuits.csv")
    df.to_sql("circuits", conn, if_exists = "replace", index = False)
    
    df = pd.read_csv("Dataset/lap_times.csv")
    df.to_sql("lap_times", conn, if_exists = "replace", index = False)
    print("Tables were populated with data!\n")
    conn.close()

# %%
def save_table_as_JSON():
    conn = sqlite3.connect("F1Results.db")
    cur = conn.cursor()
    
    rows = cur.execute("""
    SELECT * from constructors
    """).fetchall()
    conn.commit()
    
    with open('constructors.json', 'w') as outfile:
        json.dump(rows, outfile)
    conn.close()
    rows = cur.execute("""
    SELECT * from drivers
    """).fetchall()
    conn.commit()
    
    with open('drivers.json', 'w') as outfile:
        json.dump(rows, outfile)
    
    rows = cur.execute("""
    SELECT * from races
    """).fetchall()
    conn.commit()
    
    with open('races.json', 'w') as outfile:
        json.dump(rows, outfile)
    
    rows = cur.execute("""
    SELECT * from pit_stops
    """).fetchall()
    conn.commit()
    
    with open('pit_stops.json', 'w') as outfile:
        json.dump(rows, outfile)
    
    rows = cur.execute("""
    SELECT * from circuits
    """).fetchall()
    conn.commit()
    
    with open('circuits.json', 'w') as outfile:
        json.dump(rows, outfile)
    
    rows = cur.execute("""
    SELECT * from lap_times
    """).fetchall()
    conn.commit()
    
    with open('lap_times.json', 'w') as outfile:
        json.dump(rows, outfile)
    
    conn.close()

# %%
def table_to_df(db_name, table_name):
    conn = sqlite3.connect(db_name)
    cur = conn.cursor()
    data = cur.execute("SELECT * FROM " + table_name)
    cols = [column[0] for column in data.description]
    df = pd.DataFrame.from_records(data.fetchall(), columns = cols)
    conn.close()
    return df

# %%
def populate_table(db_name, table_name, path = "Dataset/"):
    conn = sqlite3.connect(db_name)
    cur = conn.cursor()
    
    df = pd.read_csv(path + table_name + ".csv")
    df.to_sql(table_name, conn, if_exists = "replace", index = False)
    conn.close()
    print(table_name + " were succesfully populated.\n")

# %%
populate_table("F1Results.db", "constructors")
# Out:
# constructors were succesfully populated.

# %%
import sqlite3

# %%
def save_table_as_JSON(db_name, table_name, file_name, path = "JSON Files/"):
    conn = sqlite3.connect(db_name)
    cur = conn.cursor()
    
    rows = cur.execute("SELECT * from " + table_name).fetchall()
    conn.commit()
    conn.close()
    with open(path + file_name + ".json", 'w') as outfile:
        json.dump(rows, outfile)
    print(file_name + ".json " + "in the given path " + "was succesfully saved.")

# %%
save_table_as_JSON("F1Results.db", "constructor_standings", "constructor_standings")
pd.read_json("JSON Files/constructor_standings.json")
# Out:
# constructor_standings.json in the given path was succesfully saved.
#            0     1    2      3   4   5   6
# 0          1    18    1   14.0   1   1   1
# 1          2    18    2    8.0   3   3   0
# 2          3    18    3    9.0   2   2   0
# 3          4    18    4    5.0   4   4   0
# 4          5    18    5    2.0   5   5   0
# 5          6    18    6    1.0   6   6   0
# 6          7    19    1   24.0   1   1   1
# 7          8    19    2   19.0   2   2   0
# 8          9    19    3    9.0   4   4   0
# 9         10    19    4    6.0   5   5   0
# 10        11    19    5    2.0   8   8   0
# 11        12    19    6   11.0   3   3   1
# 12        13    19    7    5.0   6   6   0
# 13        14    19    9    2.0   7   7   0
# 14        15    19   11    0.0   9   9   0
# 15        16    19   10    0.0  10  10   0
# 16        17    19    8    0.0  11  11   0
# 17        18    20    1   28.0   3   3   1
# 18        19    20    2   30.0   1   1   0
# ...

# %%
def circuits_per_country(db_name = "F1Results.db", table_name = "circuits"):
    data = table_to_df(db_name, table_name)
    d = data.groupby(data.country, as_index = False).count()
    d = d[["country", "circuitId"]]
    d = d.rename(columns = {"circuitId" : "number of circuits"})
    return d

# %%
def plot_data(df, x, y, kind_of_plot, fig_size, fig_color, text_size):
    df.plot(x, y, kind = kind_of_plot, figsize = fig_size, color = fig_color)
    plt.xlabel(x, size = text_size)
    plt.ylabel(y, size= text_size)
    plt.legend(fontsize= text_size)
    plt.xticks(size= text_size)
    plt.yticks(size= text_size)
    plt.show()

# %%
plot_data(circuits_per_country(), "country", "number of circuits", "bar", (15,5), "green", 20)

# %%
def races_per_year(db_name = "F1Results.db", table_name = "races"):
    data = table_to_df(db_name, table_name)
    d = data.groupby("year", as_index = False).count()
    d = d[["year", "raceId"]]
    d = d.rename(columns={"raceId": "number of races"})
    return d

# %%
def constructors_per_nationality(db_name = "F1Results.db", table_name = "constructors"):
    data = table_to_df(db_name, table_name)
    d = data.groupby("nationality", as_index = False).count()
    d = d[["nationality", "constructorId"]]
    d = d.rename(columns={"constructorId": "number of constructors"})
    return d

# %%
def drivers_per_nationality(db_name = "F1Results.db", table_name = "drivers"):
    data = table_to_df(db_name, table_name)
    d = data.groupby("nationality", as_index = False).count()
    d = d[["nationality", "driverId"]]
    d = d.rename(columns={"driverId": "number of drivers"})
    return d

# %%
def lapTimes_trend(db_name = "F1Results.db"):
    data = table_to_df(db_name, "lap_times")
    data2 = table_to_df(db_name, "races")
    result = pd.merge(data,data2,on="raceId")
    cid = result.circuitId.unique()
    dr = result.groupby("circuitId", as_index=False)["milliseconds"].agg(min)
    dr = pd.merge(dr,data2,on="circuitId")
    dr = dr[["date", "milliseconds"]]
    dr["date"] = pd.to_datetime(dr["date"])
    dr.index = dr.date
    dr = dr.drop("date", axis=1)
    start_date = datetime(1995,1,1)
    end_date = datetime(2022,1,1)
    return dr[(start_date <= dr.index) & (dr.index <= end_date)]

# %%
def pitStops_trend(db_name = "F1Results.db"):
    data = table_to_df(db_name, "pit_stops")
    data2 = table_to_df(db_name, "constructor_results")
    data4 = table_to_df(db_name, "races")
    result2 = pd.merge(data,data2, on="raceId")
    result2 = pd.merge(result2, data4, on="raceId")
    result2 = result2[result2.circuitId == 7]
    dr2 = result2.groupby("constructorId", as_index=False)[["date", "milliseconds"]]
    dr2 = dr2.apply(lambda x: x)
    dr2["date"] = pd.to_datetime(dr2["date"])
    dr2.index = dr2.date
    dr2 = dr2.drop("date", axis=1)
    start_date = datetime(1995,1,1)
    end_date = datetime(2022,1,1)
    return dr2[(start_date <= dr2.index) & (dr2.index <= end_date)]

# %%
def trend_plot(trend_data, fig_size, x_label, y_label, grid_status, text_size,):
    plt.rcParams["figure.figsize"] = [12.0,8.0]
    trend_data.plot(grid = grid_status, figsize = fig_size)
    plt.xticks(size = text_size)
    plt.yticks(size= text_size)
    plt.xlabel(x_label, size = text_size)
    plt.ylabel(y_label, size = text_size)
    plt.legend(fontsize= text_size, loc="best")
    plt.show()

# %%
trend_plot(lapTimes_trend(), (20,10), "years", "lap times (ms)", True, 25)

# %%
def points_per_constructor(db_name = "F1Results.db"):
    data = table_to_df(db_name, "constructor_results")
    data2 = table_to_df(db_name, "constructors")
    d = data.groupby("constructorId", as_index=False).count()
    d = d.apply(lambda x: x)
    d = pd.merge(data2, d, on="constructorId")
    d = d[["points", "constructorId", "name"]]
    d_a = d.loc[(d["constructorId"] > 0) & (d["constructorId"] <= 72)]
    d_b = d.loc[(d["constructorId"] > 72) & (d["constructorId"] <= 134)]
    d_c = d.loc[(d["constructorId"] > 134) & (d["constructorId"] <= 214)]
    return d_a, d_b, d_c

# %%
def races_per_constructor(db_name = "F1Results.db"):
    data = table_to_df(db_name, "constructor_standings")
    data2 = table_to_df(db_name, "constructors")
    d = data.groupby("constructorId", as_index=False).count()
    d = d.apply(lambda x: x)
    d = pd.merge(data2, d, on="constructorId")
    d = d[["raceId", "constructorId", "name"]]
    d = d.rename({"raceId": "number of races"})
    d_a = d.loc[(d["constructorId"] > 0) & (d["constructorId"] <= 72)]
    d_b = d.loc[(d["constructorId"] > 72) & (d["constructorId"] <= 134)]
    d_c = d.loc[(d["constructorId"] > 134) & (d["constructorId"] <= 214)]
    return d_a, d_b, d_c

# %%
data = table_to_df(db_name, "constructor_standings")
data2 = table_to_df(db_name, "constructors")
d = data.groupby("constructorId", as_index=False).count()
d = d.apply(lambda x: x)
d = pd.merge(data2, d, on="constructorId")
d = d[["raceId", "constructorId", "name"]]
d = d.rename({"raceId": "number of races"})
d_a = d.loc[(d["constructorId"] > 0) & (d["constructorId"] <= 72)]
d_b = d.loc[(d["constructorId"] > 72) & (d["constructorId"] <= 134)]
d_c = d.loc[(d["constructorId"] > 134) & (d["constructorId"] <= 214)]
